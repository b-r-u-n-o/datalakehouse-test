# %%
from confluent_kafka import Consumer
from time import sleep

# %%
class ExampleConsumer:
    broker = "kafka-broker:9092"
    topic = "user"
    group_id = "python"

    def start_listener(self):
        consumer_config = {
            'bootstrap.servers': self.broker,
            'group.id': self.group_id,
            'auto.offset.reset': 'latest',
            'enable.auto.commit': 'false',
            'max.poll.interval.ms': '86400000'
        }

        consumer = Consumer(consumer_config)
        consumer.subscribe([self.topic])

        try:
            while True:
                #print("Listening")
                # read single message at a time
                msg = consumer.poll(0)
                
                if msg is None:
                    sleep(5)
                    continue
                if msg.error():
                    print("Error reading message : {}".format(msg.error()))
                    continue
                # You can parse message and save to data base here
                print('----------------------------')
                print("partition: {} \n offset: {} \n topic: {} \n timestamp: {} \n value: {}".format(msg.partition(), msg.offset(),msg.topic(),msg.timestamp(),msg.value()))
                #sua regra
                                
                consumer.commit()

        except Exception as ex:
            print("Kafka Exception : {}", ex)

        finally:
            print("closing consumer")
            consumer.close()

# %%
#RUNNING CONSUMER FOR READING MESSAGE FROM THE KAFKA TOPIC
my_consumer = ExampleConsumer()
my_consumer.start_listener()
# Out:
# ----------------------------
# partition: 0
#  offset: 542
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 5079, "uid": "53a35a22-ed91-469b-b95a-e44d9f34f23d", "password": "JTO4pKCZ8N", "first_name": "Clyde", "last_name": "Heidenreich", "username": "clyde.heidenreich", "email": "clyde.heidenreich@email.com", "avatar": "https://robohash.org/laborefacilisconsequatur.png?size=300x300&set=set1", "gender": "Non-binary", "phone_number": "+976 907-177-1650", "social_insurance_number": "933367344", "date_of_birth": "1985-04-06", "employment": {"title": "Marketing Administrator", "key_skill": "Technical savvy"}, "address": {"city": "Teraborough", "street_name": "Cummings Rue", "street_address": "698 MacGyver Place", "zip_code": "66359-6163", "state": "New York", "country": "United States", "coordinates": {"lat": 62.90148936330576, "lng": 169.98277954085057}}, "credit_card": {"cc_number": "6771-8973-0085-9793"}, "subscription": {"plan": "Silver", "status": "Blocked", "payment_method": "Paypal", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 543
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 2448, "uid": "36622e7b-497b-4146-a690-3961a1e50cd8", "password": "UxXuG4HejN", "first_name": "Tamra", "last_name": "Huel", "username": "tamra.huel", "email": "tamra.huel@email.com", "avatar": "https://robohash.org/sintveritatisvel.png?size=300x300&set=set1", "gender": "Polygender", "phone_number": "+57 (785) 425-3920 x776", "social_insurance_number": "682461108", "date_of_birth": "1963-09-30", "employment": {"title": "District Healthcare Technician", "key_skill": "Problem solving"}, "address": {"city": "Port Johnny", "street_name": "Dean Extensions", "street_address": "582 Zachery Spur", "zip_code": "20932", "state": "Georgia", "country": "United States", "coordinates": {"lat": 13.964686448522954, "lng": -90.4349056973809}}, "credit_card": {"cc_number": "4198-2127-6786-6754"}, "subscription": {"plan": "Silver", "status": "Idle", "payment_method": "Cheque", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 544
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 9366, "uid": "c029e140-3060-44f3-824c-a108ca26629f", "password": "X8GYycDthS", "first_name": "Denis", "last_name": "Keeling", "username": "denis.keeling", "email": "denis.keeling@email.com", "avatar": "https://robohash.org/liberoassumendaet.png?size=300x300&set=set1", "gender": "Genderfluid", "phone_number": "+1-869 (240) 371-5916", "social_insurance_number": "163755333", "date_of_birth": "1999-05-18", "employment": {"title": "Internal Retail Assistant", "key_skill": "Leadership"}, "address": {"city": "East Rodgerview", "street_name": "Jaskolski Plains", "street_address": "235 Laurel Plaza", "zip_code": "22166", "state": "Georgia", "country": "United States", "coordinates": {"lat": 8.563461771682839, "lng": 111.49867420796454}}, "credit_card": {"cc_number": "5363-6418-0409-8474"}, "subscription": {"plan": "Bronze", "status": "Blocked", "payment_method": "Bitcoins", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 545
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 227, "uid": "e8a36b8a-a577-4203-8f87-8d578530fc1f", "password": "pNisFlv6mh", "first_name": "Terrell", "last_name": "Fisher", "username": "terrell.fisher", "email": "terrell.fisher@email.com", "avatar": "https://robohash.org/remsintminima.png?size=300x300&set=set1", "gender": "Genderqueer", "phone_number": "+61 (312) 069-4956 x193", "social_insurance_number": "582834073", "date_of_birth": "1999-01-03", "employment": {"title": "Global Technician", "key_skill": "Communication"}, "address": {"city": "Susanneside", "street_name": "Royce Throughway", "street_address": "49315 Emma Inlet", "zip_code": "21525-6321", "state": "Massachusetts", "country": "United States", "coordinates": {"lat": -77.9017940959624, "lng": -135.23645914587027}}, "credit_card": {"cc_number": "5513-0599-1968-8817"}, "subscription": {"plan": "Gold", "status": "Blocked", "payment_method": "Visa checkout", "term": "Full subscription"}}'
# ----------------------------
# partition: 0
#  offset: 546
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 2836, "uid": "2e7083ff-0521-4b1e-8bd4-bb0dd7e84def", "password": "Jo5pHYqXaK", "first_name": "Philomena", "last_name": "Stamm", "username": "philomena.stamm", "email": "philomena.stamm@email.com", "avatar": "https://robohash.org/quiaaperiammaiores.png?size=300x300&set=set1", "gender": "Polygender", "phone_number": "+376 1-851-663-8022", "social_insurance_number": "782889729", "date_of_birth": "1986-01-27", "employment": {"title": "Regional Marketing Orchestrator", "key_skill": "Problem solving"}, "address": {"city": "Elainehaven", "street_name": "Emmy Fork", "street_address": "143 Josephina Village", "zip_code": "69425-4214", "state": "Arizona", "country": "United States", "coordinates": {"lat": -72.29606316215201, "lng": 63.485259186091895}}, "credit_card": {"cc_number": "6771-8929-4080-4028"}, "subscription": {"plan": "Free Trial", "status": "Active", "payment_method": "Google Pay", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 547
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 610, "uid": "f1491137-a947-4779-9194-aecc286c1142", "password": "WqZVpMd8Pu", "first_name": "Amberly", "last_name": "Mayer", "username": "amberly.mayer", "email": "amberly.mayer@email.com", "avatar": "https://robohash.org/accusamusestquia.png?size=300x300&set=set1", "gender": "Bigender", "phone_number": "+228 871.982.4642 x2046", "social_insurance_number": "974439044", "date_of_birth": "1963-04-19", "employment": {"title": "Future Administration Agent", "key_skill": "Problem solving"}, "address": {"city": "Lake Adelafort", "street_name": "Bayer Dam", "street_address": "452 Daren Heights", "zip_code": "07031-8514", "state": "Montana", "country": "United States", "coordinates": {"lat": -84.67872726881956, "lng": 146.1792333392512}}, "credit_card": {"cc_number": "6771-8935-9728-7905"}, "subscription": {"plan": "Free Trial", "status": "Pending", "payment_method": "Debit card", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 548
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 5669, "uid": "0fd9a772-1313-41c9-8f60-c813541dde8a", "password": "mx5iJPZ8uR", "first_name": "Darius", "last_name": "Crooks", "username": "darius.crooks", "email": "darius.crooks@email.com", "avatar": "https://robohash.org/quietvoluptatem.png?size=300x300&set=set1", "gender": "Genderfluid", "phone_number": "+40 (480) 175-4971 x2637", "social_insurance_number": "148047103", "date_of_birth": "1996-09-12", "employment": {"title": "Marketing Assistant", "key_skill": "Technical savvy"}, "address": {"city": "Port Solangehaven", "street_name": "Morissette Turnpike", "street_address": "880 Cassin Villages", "zip_code": "76836", "state": "Wisconsin", "country": "United States", "coordinates": {"lat": -30.95512048378081, "lng": 103.32098997674927}}, "credit_card": {"cc_number": "4294597421143"}, "subscription": {"plan": "Silver", "status": "Active", "payment_method": "Google Pay", "term": "Payment in advance"}}'
# ----------------------------
# partition: 0
#  offset: 549
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 2853, "uid": "3082850d-6b9b-4546-ab24-b56c51162114", "password": "A728ExGrFh", "first_name": "Ozzie", "last_name": "Daniel", "username": "ozzie.daniel", "email": "ozzie.daniel@email.com", "avatar": "https://robohash.org/veniametadipisci.png?size=300x300&set=set1", "gender": "Genderfluid", "phone_number": "+964 1-380-090-9760 x65468", "social_insurance_number": "375655966", "date_of_birth": "2001-08-31", "employment": {"title": "Legal Manager", "key_skill": "Communication"}, "address": {"city": "East Stephenside", "street_name": "Krajcik Flat", "street_address": "686 Kozey Harbor", "zip_code": "61714", "state": "Arkansas", "country": "United States", "coordinates": {"lat": -70.53539588295001, "lng": 91.74004937106992}}, "credit_card": {"cc_number": "6771-8989-5231-1117"}, "subscription": {"plan": "Standard", "status": "Blocked", "payment_method": "Google Pay", "term": "Annual"}}'
# ----------------------------
# partition: 0
#  offset: 550
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 1426, "uid": "08eb9a19-1bbe-41ac-86eb-61c3a461bb11", "password": "50vGHpMkU1", "first_name": "Marlon", "last_name": "Franecki", "username": "marlon.franecki", "email": "marlon.franecki@email.com", "avatar": "https://robohash.org/delectusvelittenetur.png?size=300x300&set=set1", "gender": "Genderfluid", "phone_number": "+253 (757) 870-3064", "social_insurance_number": "719908618", "date_of_birth": "1962-09-15", "employment": {"title": "Forward Officer", "key_skill": "Technical savvy"}, "address": {"city": "North Budmouth", "street_name": "Strosin Ranch", "street_address": "566 Stamm Trafficway", "zip_code": "54786", "state": "South Carolina", "country": "United States", "coordinates": {"lat": -5.181996046889793, "lng": 107.0959645766174}}, "credit_card": {"cc_number": "5565-3461-3575-6875"}, "subscription": {"plan": "Starter", "status": "Idle", "payment_method": "WeChat Pay", "term": "Payment in advance"}}'
# ----------------------------
# partition: 0
#  offset: 551
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 1774, "uid": "d29c33b9-288d-4102-8665-deae8d25af71", "password": "RXLOaJH1Vo", "first_name": "Duncan", "last_name": "Jaskolski", "username": "duncan.jaskolski", "email": "duncan.jaskolski@email.com", "avatar": "https://robohash.org/sedaspernaturlabore.png?size=300x300&set=set1", "gender": "Female", "phone_number": "+962 742.820.0099 x85310", "social_insurance_number": "263552226", "date_of_birth": "2002-12-22", "employment": {"title": "Product Specialist", "key_skill": "Networking skills"}, "address": {"city": "Dooleyland", "street_name": "Mario Hills", "street_address": "26307 Hayes Lodge", "zip_code": "63748", "state": "Massachusetts", "country": "United States", "coordinates": {"lat": 64.81679127183665, "lng": -166.81624867373034}}, "credit_card": {"cc_number": "6771-8970-8559-0704"}, "subscription": {"plan": "Free Trial", "status": "Active", "payment_method": "Cheque", "term": "Payment in advance"}}'
# ----------------------------
# partition: 0
#  offset: 552
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 548, "uid": "dd503cbd-ef62-4cbf-b96f-d8ee2190c26a", "password": "o2d7cjlxKh", "first_name": "Tristan", "last_name": "Jast", "username": "tristan.jast", "email": "tristan.jast@email.com", "avatar": "https://robohash.org/iustoautemlaboriosam.png?size=300x300&set=set1", "gender": "Non-binary", "phone_number": "+30 486.082.3239 x172", "social_insurance_number": "321079493", "date_of_birth": "2004-03-23", "employment": {"title": "Farming Director", "key_skill": "Communication"}, "address": {"city": "Littleside", "street_name": "Wehner Terrace", "street_address": "31594 Ferdinand Rapid", "zip_code": "35212", "state": "Maryland", "country": "United States", "coordinates": {"lat": -15.288839168727478, "lng": -143.68306698206274}}, "credit_card": {"cc_number": "5396-3342-9211-9843"}, "subscription": {"plan": "Silver", "status": "Idle", "payment_method": "Apple Pay", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 553
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 3767, "uid": "be767e9e-3e91-4848-ae97-379514ccaf49", "password": "FDCezX0lZj", "first_name": "Jutta", "last_name": "Swaniawski", "username": "jutta.swaniawski", "email": "jutta.swaniawski@email.com", "avatar": "https://robohash.org/erroromnisnihil.png?size=300x300&set=set1", "gender": "Agender", "phone_number": "+53 952-501-3459 x8851", "social_insurance_number": "250749561", "date_of_birth": "1971-07-08", "employment": {"title": "Central Orchestrator", "key_skill": "Communication"}, "address": {"city": "South Nicolettechester", "street_name": "Armstrong Avenue", "street_address": "7823 Angle Mission", "zip_code": "92540", "state": "Hawaii", "country": "United States", "coordinates": {"lat": 7.817247341460259, "lng": -144.7548340283462}}, "credit_card": {"cc_number": "6771-8997-1196-2109"}, "subscription": {"plan": "Bronze", "status": "Active", "payment_method": "Credit card", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 554
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 5006, "uid": "43bf3284-86e5-49d0-b31d-2bb134708a0b", "password": "u3wf0UHD6x", "first_name": "Cody", "last_name": "Bailey", "username": "cody.bailey", "email": "cody.bailey@email.com", "avatar": "https://robohash.org/autullamatque.png?size=300x300&set=set1", "gender": "Non-binary", "phone_number": "+380 (209) 651-6014 x067", "social_insurance_number": "695134197", "date_of_birth": "1984-03-20", "employment": {"title": "Administration Specialist", "key_skill": "Work under pressure"}, "address": {"city": "West Kyle", "street_name": "Alexandra Point", "street_address": "3268 Kelley Ridge", "zip_code": "26113-1079", "state": "Hawaii", "country": "United States", "coordinates": {"lat": -57.615797580025514, "lng": 119.93261461632966}}, "credit_card": {"cc_number": "6771-8931-3649-1760"}, "subscription": {"plan": "Business", "status": "Blocked", "payment_method": "Apple Pay", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 555
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 1275, "uid": "ecebf0b4-8d59-485a-ac45-9055e7df7f40", "password": "GPhjsySQW4", "first_name": "Elizbeth", "last_name": "Feest", "username": "elizbeth.feest", "email": "elizbeth.feest@email.com", "avatar": "https://robohash.org/consequaturquimagnam.png?size=300x300&set=set1", "gender": "Polygender", "phone_number": "+261 511.047.6667", "social_insurance_number": "577502735", "date_of_birth": "1995-05-16", "employment": {"title": "Product Manufacturing Director", "key_skill": "Fast learner"}, "address": {"city": "South Albert", "street_name": "Ortiz Greens", "street_address": "61651 McGlynn Crossing", "zip_code": "91578", "state": "Iowa", "country": "United States", "coordinates": {"lat": -49.56300571900756, "lng": -157.2177531374121}}, "credit_card": {"cc_number": "4689114299957"}, "subscription": {"plan": "Basic", "status": "Idle", "payment_method": "Credit card", "term": "Full subscription"}}'
# ----------------------------
# partition: 0
#  offset: 556
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 3878, "uid": "29ec566a-93da-4254-a263-c268eac4290b", "password": "yDeQvzr3qM", "first_name": "Daisy", "last_name": "Kreiger", "username": "daisy.kreiger", "email": "daisy.kreiger@email.com", "avatar": "https://robohash.org/temporainventoreesse.png?size=300x300&set=set1", "gender": "Male", "phone_number": "+44 1-533-524-8076 x29608", "social_insurance_number": "662515543", "date_of_birth": "1997-01-12", "employment": {"title": "Internal Marketing Manager", "key_skill": "Work under pressure"}, "address": {"city": "Kuhlmanmouth", "street_name": "Boyer Trail", "street_address": "66306 Zemlak Road", "zip_code": "08545-4809", "state": "Montana", "country": "United States", "coordinates": {"lat": -33.46077208140519, "lng": -160.21276351506003}}, "credit_card": {"cc_number": "4822876253330"}, "subscription": {"plan": "Diamond", "status": "Blocked", "payment_method": "Apple Pay", "term": "Annual"}}'
# ----------------------------
# partition: 0
#  offset: 557
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 3398, "uid": "e7ac67d7-21d1-4567-9fe4-298f741a14f6", "password": "JQ8YGi4WjM", "first_name": "Latrisha", "last_name": "Konopelski", "username": "latrisha.konopelski", "email": "latrisha.konopelski@email.com", "avatar": "https://robohash.org/numquamtotamporro.png?size=300x300&set=set1", "gender": "Female", "phone_number": "+230 240.469.0952 x0377", "social_insurance_number": "476514500", "date_of_birth": "1996-08-29", "employment": {"title": "Product Real-Estate Technician", "key_skill": "Teamwork"}, "address": {"city": "Sanfordville", "street_name": "Whitney Gateway", "street_address": "8638 Lynch Roads", "zip_code": "58761", "state": "Missouri", "country": "United States", "coordinates": {"lat": 79.25980357937809, "lng": -57.96378059852677}}, "credit_card": {"cc_number": "5347-6092-2964-0791"}, "subscription": {"plan": "Platinum", "status": "Pending", "payment_method": "Alipay", "term": "Annual"}}'
# ----------------------------
# partition: 0
#  offset: 558
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 8431, "uid": "fefa1d02-4a87-433c-8b4d-aca846235793", "password": "fHRFze9hKk", "first_name": "Lynwood", "last_name": "Conn", "username": "lynwood.conn", "email": "lynwood.conn@email.com", "avatar": "https://robohash.org/blanditiiseositaque.png?size=300x300&set=set1", "gender": "Polygender", "phone_number": "+682 (550) 321-8519 x58447", "social_insurance_number": "480165240", "date_of_birth": "2005-06-30", "employment": {"title": "Global Government Manager", "key_skill": "Networking skills"}, "address": {"city": "O\'Harafort", "street_name": "Vernita Forges", "street_address": "687 Smitham Terrace", "zip_code": "82435", "state": "Indiana", "country": "United States", "coordinates": {"lat": -37.87813033492094, "lng": 154.7327083687788}}, "credit_card": {"cc_number": "6771-8954-8018-0204"}, "subscription": {"plan": "Essential", "status": "Pending", "payment_method": "Debit card", "term": "Full subscription"}}'
# ----------------------------
# partition: 0
#  offset: 559
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 3811, "uid": "4a272ea3-594b-4658-a1c2-4f76d44f6848", "password": "XNPB4q9ySL", "first_name": "Quinn", "last_name": "Yundt", "username": "quinn.yundt", "email": "quinn.yundt@email.com", "avatar": "https://robohash.org/illumducimusneque.png?size=300x300&set=set1", "gender": "Agender", "phone_number": "+1-246 767-312-1323", "social_insurance_number": "370239295", "date_of_birth": "1961-08-20", "employment": {"title": "Legacy Technology Facilitator", "key_skill": "Confidence"}, "address": {"city": "Terraland", "street_name": "Logan Wall", "street_address": "159 Laurence Flats", "zip_code": "29881", "state": "Hawaii", "country": "United States", "coordinates": {"lat": 30.203727877745607, "lng": -57.556912462857554}}, "credit_card": {"cc_number": "4519-1112-5005-1282"}, "subscription": {"plan": "Platinum", "status": "Active", "payment_method": "Cash", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 560
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 97, "uid": "e6c42f35-f845-4312-8f08-a536ad2bec25", "password": "NMHAW20c73", "first_name": "Leigh", "last_name": "Klein", "username": "leigh.klein", "email": "leigh.klein@email.com", "avatar": "https://robohash.org/nihillaboreet.png?size=300x300&set=set1", "gender": "Bigender", "phone_number": "+31 1-390-604-8506", "social_insurance_number": "581751617", "date_of_birth": "1960-06-23", "employment": {"title": "Marketing Analyst", "key_skill": "Organisation"}, "address": {"city": "Lloydhaven", "street_name": "Cummings Mill", "street_address": "80784 Dwain Shores", "zip_code": "71261", "state": "Georgia", "country": "United States", "coordinates": {"lat": -59.62879419708295, "lng": -102.16827203728455}}, "credit_card": {"cc_number": "4603658184954"}, "subscription": {"plan": "Professional", "status": "Pending", "payment_method": "Cash", "term": "Monthly"}}'
# ----------------------------
# partition: 0
#  offset: 561
#  topic: user
#  timestamp: (1, -1)
#  value: b'{"id": 9340, "uid": "06ddee61-5845-4433-b071-5d1bce517549", "password": "j4mzBH2ZfE", "first_name": "Kizzy", "last_name": "Sipes", "username": "kizzy.sipes", "email": "kizzy.sipes@email.com", "avatar": "https://robohash.org/facilisquoipsum.png?size=300x300&set=set1", "gender": "Genderfluid", "phone_number": "+234 676-550-0037 x1206", "social_insurance_number": "929660298", "date_of_birth": "1997-11-27", "employment": {"title": "Forward Sales Consultant", "key_skill": "Communication"}, "address": {"city": "Tarshamouth", "street_name": "Hudson Mount", "street_address": "100 Hane Inlet", "zip_code": "58077", "state": "Michigan", "country": "United States", "coordinates": {"lat": -11.323400537896575, "lng": -79.49930434452506}}, "credit_card": {"cc_number": "6771-8982-1777-1246"}, "subscription": {"plan": "Diamond", "status": "Idle", "payment_method": "Apple Pay", "term": "Payment in advance"}}'
